# %% [markdown]
# # Binary Search, Linked List and Complexity

# %% [markdown]
# ## How to appraoch a DSA question
#
# Here's a systematic strategy we'll apply for solving problems:
#
# 1. State the problem clearly. Identify the input & output formats.
# 2. Come up with some example inputs & outputs. Try to cover all edge cases.
# 3. Come up with a correct solution for the problem. State it in plain English.
# 4. Implement the solution and test it using example inputs. Fix bugs, if any.
# 5. Analyze the algorithm's complexity and identify inefficiencies, if any.
# 6. Apply the right technique to overcome the inefficiency. Repeat steps 3 to 6.
#
# Applying the right technique" is where the knowledge of common data structures and algorithms comes in handy.

# %% [markdown]
# ### Binary Search

# %% [markdown]
# QUESTION 1:
#
#  Alice has some cards with numbers written on them. She arranges the cards in decreasing order, and lays them out face down in a sequence on a table. She challenges Bob to pick out the card containing a given number by turning over as few cards as possible. Write a function to help Bob locate the card.

# %%
#write test case in dict 
#what if query is not in card
test_1 = {
    "input": {
        "cards": [],
        "query": 3
    },
    "output": -1
}
#what if query appears more than once
test_2={
    "input": {
        "cards": [20,10,9,6,3,1],
        "query": 3
    },
    "output": 1
    }
test_3={
    "input": {
        "cards": [20,15,14,9,8],
        "query": 8
    },
    "output": 4
}

test_cases=[]
test_cases.append(test_1)
test_cases.append(test_2)
test_cases.append(test_3)

# %%
def locate_card(cards, query):
    if query not in cards:
        return -1
    
    if cards.count(query) > 1:
        print(f"{query} occurse  {cards.count(query)} times in the list")
        return f"The first occurance of the query is at index {cards.index(query)}"

    return cards.index(query)

# %%
def locate_card_b_search(cards:list,query:int):
    if query not in cards:
        return -1
    
    point=len(cards)//2
    cards_original=cards.copy()
    while True:
        
        print(cards)
        print("current index ", point, "val", cards[point])
        if query == cards[point]:
            return point
        elif query>cards[point]:
            point+= len(cards[:point])//2
        else:
            point-= len(cards[:point])//2

# %%
test_2["input"]
# Out:
# {'cards': [20, 10, 9, 6, 3, 1], 'query': 3}

# %%
locate_card_b_search(**test_2["input"])
# Out:
# [20, 10, 9, 6, 3, 1]
# current index  3 val 6
# [20, 10, 9, 6, 3, 1]
# current index  2 val 9
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# ...
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1 val 10
# [20, 10, 9, 6, 3, 1]
# current index  1
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# /Users/mufti/Muftawo/DSA/Questions.ipynb Cell 9 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/mufti/Muftawo/DSA/Questions.ipynb#ch0000006?line=0'>1</a> locate_card_b_search(**test_2["input"])
#
# /Users/mufti/Muftawo/DSA/Questions.ipynb Cell 9 in locate_card_b_search(cards, query)
#       <a href='vscode-notebook-cell:/Users/mufti/Muftawo/DSA/Questions.ipynb#ch0000006?line=6'>7</a> while True:
#       <a href='vscode-notebook-cell:/Users/mufti/Muftawo/DSA/Questions.ipynb#ch0000006?line=8'>9</a>     print(cards)
# ---> <a href='vscode-notebook-cell:/Users/mufti/Muftawo/DSA/Questions.ipynb#ch0000006?line=9'>10</a>     print("current index ", point, "val", cards[point])
#      <a href='vscode-notebook-cell:/Users/mufti/Muftawo/DSA/Questions.ipynb#ch0000006?line=10'>11</a>     if query == cards[point]:
#      <a href='vscode-notebook-cell:/Users/mufti/Muftawo/DSA/Questions.ipynb#ch0000006?line=11'>12</a>         return point
#
# File ~/miniconda3/envs/home/lib/python3.8/site-packages/ipykernel/iostream.py:402, in OutStream.write(self, string)
#     400 is_child = (not self._is_master_process())
#     401 # only touch the buffer in the IO thread to avoid races
# --> 402 self.pub_thread.schedule(lambda : self._buffer.write(string))
#     403 if is_child:
#     404     # mp.Pool cannot be trusted to flush promptly (or ever),
#     405     # and this helps.
#     406     if self._subprocess_flush_pending:
#
# File ~/miniconda3/envs/home/lib/python3.8/site-packages/ipykernel/iostream.py:203, in IOPubThread.schedule(self, f)
#     201     self._events.append(f)
#     202     # wake event thread (message content is ignored)
# --> 203     self._event_pipe.send(b'')
#     204 else:
#     205     f()
#
# File ~/miniconda3/envs/home/lib/python3.8/site-packages/zmq/sugar/socket.py:547, in Socket.send(self, data, flags, copy, track, routing_id, group)
#     540         data = zmq.Frame(
#     541             data,
#     542             track=track,
#     543             copy=copy or None,
#     544             copy_threshold=self.copy_threshold,
#     545         )
#     546     data.group = group
# --> 547 return super(Socket, self).send(data, flags=flags, copy=copy, track=track)
#
# File zmq/backend/cython/socket.pyx:718, in zmq.backend.cython.socket.Socket.send()
#
# File zmq/backend/cython/socket.pyx:765, in zmq.backend.cython.socket.Socket.send()
#
# File zmq/backend/cython/socket.pyx:242, in zmq.backend.cython.socket._send_copy()
#
# File ~/miniconda3/envs/home/lib/python3.8/site-packages/zmq/backend/cython/checkrc.pxd:13, in zmq.backend.cython.checkrc._check_rc()
#
# KeyboardInterrupt:

# %%
[3,4,5,56]//2
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /Users/mufti/Muftawo/DSA/Questions.ipynb Cell 10 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/mufti/Muftawo/DSA/Questions.ipynb#ch0000007?line=0'>1</a> [3,4,5,56]//2
#
# TypeError: unsupported operand type(s) for //: 'list' and 'int'

# %%
cards
# Out:
# [1, 3, 4, 5, 5, 6, 76]

# %%
def encode(input_string):
    count = 1
    prev = ""
    lst = []
    for character in input_string:
        if character != prev:
            if prev:
                entry = (prev, count)
                lst.append(entry)
            count = 1
            prev = character
        else:
            count += 1
    entry = (character, count)
    lst.append(entry)
    return lst


def decode(lst):
    q = ""
    for character, count in lst:
        q += character * count
    return q

# %%
from hypothesis import given, strategies



@given(strategies.text())
def test_decode_inverts_encode(s):
    assert decode(encode(s)) == s

# %%
def mid_of_k(n,k, arr):
    assert n == len(arr)
    assert k in arr
    begin_index = 0
    end_index = n - 1
    while begin_index <= end_index:
        mid_index = (begin_index + end_index) // 2
        print(f"begin_index: {begin_index}, end_index: {end_index}, mid_index: {mid_index}")
        if arr[:mid_index].count(k) == arr[mid_index+1:].count(k):
            return mid_index
        elif arr[:mid_index].count(k) > arr[mid_index+1:].count(k):
            end_index = mid_index - 1
        elif arr[:mid_index].count(k) < arr[mid_index+1:].count(k):
            begin_index = mid_index + 1
    return "Something is wrong"

# %%
def contains_same_k(N:int,k:int , arr:list):
    
    for i in range(0,N):
        if arr[:i].count(k) == arr[i+1:].count(k):
            return i 
    
    return "Cannot balance array"

# %%
N= 5
K = 3
arr = [1,2,3,3,3]

contains_same_k(N,K,arr)
# Out:
# 3

# %%
ls=[6,7,8,8,9,9,00,0,1]

# %%
ls[1:]
# Out:
# [7, 8, 8, 9, 9, 0, 0, 1]

# %% [markdown]
# 1. #### Block Distance
#
# In a neighboughood with a series of blocks, we want to pick the ideal building for our client given s/he has some specific aminities s/he needs to live close to.
#
# The block with the least distance to the selected aminities is the optimal block
#
# Given a list of blocks and the aminities in present in the each block and clients needs find the optimal block for the client.
#
#
# dist=dict()
#
# sample input | blocks =[{'Hospital':false,
#                         'school':true,
#                         'airport':false,
#                         'gym':true},
#
#                         {'Hospital':true,
#                         'school':false,
#                         'airport':false,
#                         'gym':true},
#
#                         {'Hospital':true,
#                         'school':true,
#                         'airport':false,
#                         'gym':true},
#
#                         {'Hospital':false,
#                         'school':true,
#                         'airport':false,
#                         'gym':true}
#
#                         {'Hospital':false,
#                         'school':true,
#                         'airport':true,
#                         'gym':true}]
#
#              | required facilities = ['Hospital','school','airport']
#
# output = index 3
#
#
#
# ### Weakest code build session
#
# In our code base we have  a series of test that we run the code againts in hourly intervals, If all the test pass we return a green light or true esle we return red light untill we are able to resolve the build
# and start a new session tracking the build.
#
# We need you to right a program that tells us what the worse build run was,
#
# Sample input | [
#     [true,true,true,false,false],
#     [true,true,true,true,false],
#     [true,true,true,true,true,true,false,false,false],
#     [true,false,false,false,false],
#     [true,true,true,true,true,true,true,true,true,true,true,true,false],
#     ['true',false],
#     [true,true,true,true,false,false]
# ]
#
#
#
# []

# %%
#  intialize a collector of blocks and max dist to travel to get all facilities
#  traverse thriugh list, keeping index and facilities,
#  intialize a collection of lenght required facilitis, each element rep  distances that can be travelled and intialize all with the maximum distcance that can be travelled
#  unpack only the need facilities in each index, 
#  At the current postion pr block, we traverse the blocks again update what the least distance for each facility is 
# update collector dict with current block as key and max of distcnce list as value

# %%
def ideal_block(blocks,needs):
    places=dict()
    needs= tuple(needs)
    for block,facilites in enumerate(blocks):
        dist=[len(blocks)]*len(needs)
        
        #if facility is available in current block replace the index in dist with zero
        
        for block_idx,fac in enumerate(blocks):
            
            
            
            
 
        
    
    
    
    
    return max(places, key=places.get)

# %%
def check_distnace(block_1,block_2,needs):
    for need in needs:
        if bloc_1

# %%
sample_input=[
    [True,True,True,False,False],
    [True,True,True,True,False],
    [True,True,True,True,True,True,False,False,False],
    [True,False,False,False,False],
    [True,True,True,True,True,True,True,True,True,True,True,True,False],
    [True,False],
    [True,True,True,True,False,False]
]

# %%
# question 2


def weakest_build(build_runs:list):
    weakest={}
    for idx,build in enumerate(build_runs):
        weakest[idx]=len(build)-sum(build)
    
    return max(weakest, key=weakest.get), weakest[max(weakest, key=weakest.get)]

# %%
weakest_build(sample_input)
# Out:
# (3, 4)

# %%
max(h:=weakest_build(sample_input ),key=h.get)
# Out:
# 3

# %%
[2]*3
# Out:
# [2, 2, 2]
